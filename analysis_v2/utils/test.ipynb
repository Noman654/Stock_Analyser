# %%
from news_fetch import *

# %%
stock_symbol = "TATAMOTORS"
encoded_stock_symbol = quote(stock_symbol)
feed_url = f'https://news.google.com/rss/search?q=stock+{encoded_stock_symbol}&hl=en-IN&gl=IN&ceid=IN:en'
feed = feedparser.parse(feed_url)

# %%
feed['entries'][0]
# Out:
# {'title': 'Tata Motors Share Price Falls By 3.57%: What Investors Need To Know Today - Local Haryana',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://news.google.com/rss/search?q=stock+TATAMOTORS&hl=en-IN&gl=IN&ceid=IN:en',
#   'value': 'Tata Motors Share Price Falls By 3.57%: What Investors Need To Know Today - Local Haryana'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://news.google.?oc=5'}],
# ...

# %%
new_decoderv1('https://news.google.?oc=5&hl=en-IN&gl=IN&ceid=IN:en')
# Out:
# {'status': True,
#  'decoded_url': 'https://localharyana.com/trending-news/tata-motors-share-price-falls-by-3-57-what-investors-need-to-know-today/'}

# %%
url ='https://localharyana.com/trending-news/tata-motors-share-price-falls-by-3-57-what-investors-need-to-know-today/'

# %%
import newspaper

# %%
article = newspaper.article(url)

# %%
from newspaper import Article
news_article = Article(entry.link)
news_article.download()
news_article.parse()
news_article.nlp()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 article.nlp()
#
# AttributeError: 'dict' object has no attribute 'nlp'

# %%
article.keyword_scores
# Out:
# {}

# %%
news_article.nlp()
